# %%
import numpy as np
import test

# %% [markdown]
# ## Test 50x50 dimension

# %% [markdown]
# ### Using different formulation

# %%
matrices, starting_points = test.initialize_matrices(50,50,1)

# %%
results_new_formulation = test.run_test(matrices, starting_points,1)

# %%
test.compute_results(results_new_formulation[0], results_new_formulation[1], results_new_formulation[2], results_new_formulation[3])
# Out:
# average gradient norm:  7.533963657952014e-05
# standard deviation gradient norm:  6.237955076961476e-05
# average number of computations: 5607.58
# standard deviation number of computations:  1728.673723870413
# average number of iterations:  93.22
# standard deviation number of iterations:  23.34805345205463
# average time:  0.021695010662078858
# standard deviation time:  0.007800111425301944
# average residual:  6.7856831265089565e-15
# standard deviation residuals:  2.9764447769098715e-15

# %% [markdown]
# ### Using Rayleigh quotient

# %%
results_rayleigh = test.run_test(matrices, starting_points,0)

# %%
test.compute_results(results_rayleigh[0], results_rayleigh[1], results_rayleigh[2], results_rayleigh[3])
# Out:
# average gradient norm:  5.338623186225048e-06
# standard deviation gradient norm:  2.116803965887426e-06
# average number of computations: 96.36
# standard deviation number of computations:  41.85272273102433
# average number of iterations:  13.58
# standard deviation number of iterations:  3.6883058441512144
# average time:  0.000759134292602539
# standard deviation time:  0.0003275604666142875
# average residual:  4.263256414560601e-14
# standard deviation residuals:  6.22951906868262e-14

# %%
time_numpy = test.numpy_test(matrices)
print('average time numpy: ', np.mean(time_numpy))
print('standard deviation time: ', np.std(time_numpy))
# Out:
# average time numpy:  0.00017163753509521484
# standard deviation time:  3.825388024361443e-05

# %%
test.plot_results(results_new_formulation[0], results_rayleigh[0], 'gradient norm'),
# Out:
# (None,)

# %%
test.plot_results(results_new_formulation[3], results_rayleigh[3], 'absolute error')

# %% [markdown]
# ## Plot alpha values

# %%
test.plot_alphas(results_new_formulation[4])

# %%
test.plot_alphas(results_rayleigh[4])

# %% [markdown]
# ## test 250x100 density 1

# %% [markdown]
# ### Using different formulation

# %%
matrices, starting_points = test.initialize_matrices(250, 100, 1)

# %%
results_new_formulation = test.run_test(matrices, starting_points, 1)

# %%
test.compute_results(results_new_formulation[0], results_new_formulation[1], results_new_formulation[2], results_new_formulation[3])
# Out:
# average gradient norm:  0.002591026923355167
# standard deviation gradient norm:  0.002361501150708505
# average number of computations: 6194.94
# standard deviation number of computations:  348.7759687822542
# average number of iterations:  101.0
# standard deviation number of iterations:  0.0
# average time:  0.08023929834365845
# standard deviation time:  0.03770636652839797
# average residual:  1.6058265828178263e-14
# standard deviation residuals:  1.5907907772083266e-14

# %% [markdown]
# ### Usign Rayleigh quotient

# %%
results_rayleigh = test.run_test(matrices, starting_points, 0)

# %%
test.compute_results(results_rayleigh[0], results_rayleigh[1], results_rayleigh[2], results_rayleigh[3])
# Out:
# average gradient norm:  5.8862626595294626e-06
# standard deviation gradient norm:  2.1669774148329715e-06
# average number of computations: 200.04
# standard deviation number of computations:  19.573410535724225
# average number of iterations:  16.16
# standard deviation number of iterations:  1.5014659503298766
# average time:  0.006750133037567139
# standard deviation time:  0.011160845901168727
# average residual:  8.526512829121202e-15
# standard deviation residuals:  8.286281022897837e-15

# %%
time_numpy = test.numpy_test(matrices)
print('average time numpy: ', np.mean(time_numpy))
print('standard deviation time: ', np.std(time_numpy))
# Out:
# average time numpy:  0.007776021957397461
# standard deviation time:  0.007579567374581583

# %%
test.plot_results(results_new_formulation[0], results_rayleigh[0], 'gradient norm')

# %%
test.plot_results(results_new_formulation[3], results_rayleigh[3], 'gap')

# %% [markdown]
# ## Plot alpha values

# %%
test.plot_alphas(results_new_formulation[4])

# %%
test.plot_alphas(results_rayleigh[4])

# %% [markdown]
# ## Test 1000x50 density 1

# %% [markdown]
# ### Using different formulation

# %%
matrices, starting_points = test.initialize_matrices(1000, 50, 1)

# %%
results_new_formulation = test.run_test(matrices, starting_points, 1)

# %%
test.compute_results(results_new_formulation[0], results_new_formulation[1], results_new_formulation[2], results_new_formulation[3])
# Out:
# average gradient norm:  0.007916240393714758
# standard deviation gradient norm:  0.0075437426846715495
# average number of computations: 6434.28
# standard deviation number of computations:  347.9266037542975
# average number of iterations:  101.0
# standard deviation number of iterations:  0.0
# average time:  0.05266413450241089
# standard deviation time:  0.006651606609226439
# average residual:  2.5437429940211587e-14
# standard deviation residuals:  1.453333488629805e-14

# %% [markdown]
# ### Using Rayleigh quotient

# %%
results_rayleigh = test.run_test(matrices, starting_points, 0)

# %%
test.compute_results(results_rayleigh[0], results_rayleigh[1], results_rayleigh[2], results_rayleigh[3])
# Out:
# average gradient norm:  6.607504846202385e-06
# standard deviation gradient norm:  3.536553154911912e-06
# average number of computations: 573.74
# standard deviation number of computations:  1329.5064469193069
# average number of iterations:  20.46
# standard deviation number of iterations:  18.646404479148252
# average time:  0.005908534526824951
# standard deviation time:  0.01204456367587278
# average residual:  1.2789769243681804e-14
# standard deviation residuals:  1.0728960028346178e-14

# %%
time_numpy = test.numpy_test(matrices)
print('average time numpy: ', np.mean(time_numpy))
print('standard deviation time: ', np.std(time_numpy))
# Out:
# average time numpy:  0.0063847780227661135
# standard deviation time:  0.008286330010356046

# %%
test.plot_results(results_new_formulation[0], results_rayleigh[0], 'gradient norm')

# %%
test.plot_results(results_new_formulation[3], results_rayleigh[3], 'gap')

# %% [markdown]
# ## Plot alpha values

# %%
test.plot_alphas(results_new_formulation[4])

# %%
test.plot_alphas(results_rayleigh[4])

# %% [markdown]
# ## Test 250x100 density 0.5

# %% [markdown]
# ### Using different formulation

# %%
matrices, starting_points = test.initialize_matrices(250, 100, 0.5)

# %%
results_new_formulation = test.run_test(matrices, starting_points, 1)

# %%
test.compute_results(results_new_formulation[0], results_new_formulation[1], results_new_formulation[2], results_new_formulation[3])
# Out:
# average gradient norm:  0.00038622271250883815
# standard deviation gradient norm:  0.0003214334548546897
# average number of computations: 5716.94
# standard deviation number of computations:  570.0382762587088
# average number of iterations:  100.38
# standard deviation number of iterations:  6.168922110061043
# average time:  0.07223391532897949
# standard deviation time:  0.031276559321645234
# average residual:  6.963318810448982e-15
# standard deviation residuals:  6.1106675275368615e-15

# %% [markdown]
# ### Using Rayleigh quotient

# %%
results_rayleigh = test.run_test(matrices, starting_points, 0)

# %%
test.compute_results(results_rayleigh[0], results_rayleigh[1], results_rayleigh[2], results_rayleigh[3])
# Out:
# average gradient norm:  5.12058193899372e-06
# standard deviation gradient norm:  2.2376814389371856e-06
# average number of computations: 112.72
# standard deviation number of computations:  12.448357321349672
# average number of iterations:  13.14
# standard deviation number of iterations:  1.4766177569025778
# average time:  0.003912453651428223
# standard deviation time:  0.008506973241769241
# average residual:  1.1581846592889632e-14
# standard deviation residuals:  1.0570382984454997e-14

# %%
time_numpy = test.numpy_test(matrices)
print('average time numpy: ', np.mean(time_numpy))
print('standard deviation time: ', np.std(time_numpy))
# Out:
# average time numpy:  0.003420424461364746
# standard deviation time:  0.0010988457338586802

# %%
test.plot_results(results_new_formulation[0], results_rayleigh[0], 'gradient norm')

# %%
test.plot_results(results_new_formulation[3], results_rayleigh[3], 'gap')

# %% [markdown]
# ## Plot alpha values

# %%
test.plot_alphas(results_new_formulation[4])

# %%
test.plot_alphas(results_rayleigh[4])

# %% [markdown]
# ## Test 1000x50 density 0.5

# %% [markdown]
# ### Using different formulation

# %%
matrices, starting_points = test.initialize_matrices(1000, 50, 0.5)

# %%
results_new_formulation = test.run_test(matrices, starting_points, 1)

# %%
test.compute_results(results_new_formulation[0], results_new_formulation[1], results_new_formulation[2], results_new_formulation[3])
# Out:
# average gradient norm:  0.0009713112481510215
# standard deviation gradient norm:  0.0008940438366596248
# average number of computations: 5823.18
# standard deviation number of computations:  562.477170736733
# average number of iterations:  100.38
# standard deviation number of iterations:  6.168922110061043
# average time:  0.0481930685043335
# standard deviation time:  0.007916603252110806
# average residual:  1.1226575225009583e-14
# standard deviation residuals:  7.327897199248661e-15

# %% [markdown]
# ### Using Rayleigh quotient

# %%
results_rayleigh = test.run_test(matrices, starting_points, 0)

# %%
test.compute_results(results_rayleigh[0], results_rayleigh[1], results_rayleigh[2], results_rayleigh[3])
# Out:
# average gradient norm:  4.799256631965997e-06
# standard deviation gradient norm:  2.272557041965345e-06
# average number of computations: 159.96
# standard deviation number of computations:  41.38645188947707
# average number of iterations:  13.82
# standard deviation number of iterations:  1.9410306540598476
# average time:  0.002015054225921631
# standard deviation time:  0.0012767629861620098
# average residual:  1.3358203432289883e-14
# standard deviation residuals:  1.3265663517489617e-14

# %%
time_numpy = test.numpy_test(matrices)
print('average time numpy: ', np.mean(time_numpy))
print('standard deviation time: ', np.std(time_numpy))
# Out:
# average time numpy:  0.0016526460647583007
# standard deviation time:  0.0009773984934169906

# %%
test.plot_results(results_new_formulation[0], results_rayleigh[0], 'gradient norm')

# %%
test.plot_results(results_new_formulation[3], results_rayleigh[3], 'gap')

# %% [markdown]
# ## Plot alpha values

# %%
test.plot_alphas(results_new_formulation[4])

# %%
test.plot_alphas(results_rayleigh[4])
